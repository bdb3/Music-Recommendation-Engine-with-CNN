# %%
songTitle = input('Welcome to the Million Song Database Recommendation Engine (MSDRE). Enter the title of a song you would like recommendations for. i.e. Bodak Yellow: ')
artist = input('Enter the name of the artist i.e. Cardi B: ')

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id = "782cc49959664a40886e2583e1c0d429", client_secret = "446c0a76446f4f4f855e8e8337400328")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
results = sp.search(q= "artist:" + artist + " track:" + songTitle, type="track", offset = 0)
trackId = results['tracks']['items'][0]['id']
albumId = results['tracks']['items'][0]['id']
aAnal = sp.audio_analysis(trackId)

# %%
bars_confidence = aAnal['bars'][0]['confidence']
bars_start = aAnal['bars'][0]['start']
beats_confidence = aAnal['beats'][0]['start']
beats_start = aAnal['beats'][0]['start']
duration = aAnal['track']['duration']
end_of_fade_in = aAnal['track']['end_of_fade_in']
key_confidence = aAnal['track']['key_confidence']
key = aAnal['track']['key']
#latitude 
#longitude - both not part of Spotify API any longer
loudness = aAnal['track']['loudness']
mode = aAnal['track']['mode']
mode_confidence = aAnal['track']['mode_confidence']
start_of_fade_out = aAnal['track']['start_of_fade_out']
tatums_confidence = aAnal['tatums'][0]['confidence']
tatums_start = aAnal['tatums'][0]['start']
tempo = aAnal['track']['tempo']
time_signature = aAnal['track']['time_signature']
time_signature_confidence = aAnal['track']['time_signature_confidence']
year = results['tracks']['items'][0]['album']['release_date'][:4]

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Danny\Documents\spring18\DataScience\FinalProject\200clusters.csv')
df = df.fillna(df.mean())
columnNames = ['bars_confidence','bars_start','beats_confidence','beats_start','duration','end_of_fade_in','key_confidence','key','loudness','mode','mode_confidence','start_of_fade_out','tatums_confidence','tatums_start','tempo','time_signature','time_signature_confidence','year']
y = df['clusters']
x= df[columnNames]
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
my_ANN = MLPClassifier(hidden_layer_sizes=(80,), activation= 'logistic', 
                       solver='adam', alpha=1e-5, random_state=1, 
                       learning_rate_init = 0.002)
my_ANN.fit(x, y)
# Out:
# MLPClassifier(activation='logistic', alpha=1e-05, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(80,), learning_rate='constant',
#        learning_rate_init=0.002, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
testSong = [bars_confidence,bars_start,beats_confidence,beats_start,duration,end_of_fade_in,key_confidence,key,loudness,mode,mode_confidence,start_of_fade_out,tatums_confidence,tatums_start,tempo,time_signature,time_signature_confidence,year]
pred = pd.DataFrame(data=[testSong])
pred.columns = ['bars_confidence','bars_start','beats_confidence','beats_start','duration','end_of_fade_in','key_confidence','key','loudness','mode','mode_confidence','start_of_fade_out','tatums_confidence','tatums_start','tempo','time_signature','time_signature_confidence','year']
ans = my_ANN.predict(pred)

# %%
dfCluster = df.loc[df['clusters'] == ans[0]]
artistId = results['tracks']['items'][0]['artists'][0]['id']

# %%
genres = sp.artist(artistId)['genres']

# %%
dfnew = dfCluster[['song.id','terms']]
dfnew['votes'] = 0
# Out:
# C:\Users\Danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
taglist = genres[0].split()
for i in range(1, len(genres)):
    taglist = taglist + genres[i].split()

# %%
indices = dfnew.index.values
for i in range(len(dfnew)):
    term = dfnew.iloc[i]['terms']
    compare = term.split()
    for j in range(len(compare)):
        for k in range(len(taglist)):
            if(compare[j]==taglist[k]):
                dfnew.at[indices[i], 'votes'] = dfnew.iloc[i]['votes'] + 1

# %%
maxVotes = 0
for i in range(len(dfnew)):
    if (dfnew.iloc[i]['votes'] > maxVotes):
        maxVotes = dfnew.iloc[i]['votes']
reccs = []
for i in range(len(dfnew)):
    if (dfnew.iloc[i]['votes'] == maxVotes):
        reccs.append(dfnew.iloc[i]['song.id'])

# %%
for i in range(len(reccs)):
    dfAns = df.loc[df['song.id'] == reccs[i]]
    print(dfAns['title'])
    print(dfAns['artist.name'])
# Out:
# 53    The Nightmare Begins
# Name: title, dtype: object
# 53    ZombieSuckers
# Name: artist.name, dtype: object
# 1613    On Efface
# Name: title, dtype: object
# 1613    Julie Zenatti
# Name: artist.name, dtype: object
# 1697    Show You How
# Name: title, dtype: object
# 1697    The Killers
# Name: artist.name, dtype: object
# 1973    You Are God (Broken Album Version)
# Name: title, dtype: object
# 1973    Darwin Hobbs
# Name: artist.name, dtype: object
# 2025    Tony Yayo Explosion
# Name: title, dtype: object
# 2025    G Unit feat. 50 Cent
# Name: artist.name, dtype: object
# 2536    Vortex
# Name: title, dtype: object
# 2536    Elliot Goldenthal
# Name: artist.name, dtype: object
# 2720    Sugar Coated Sour
# Name: title, dtype: object
# 2720    The Dillinger Escape Plan
# Name: artist.name, dtype: object
# 2986    Pennies From Heaven
# Name: title, dtype: object
# 2986    Dean Martin
# Name: artist.name, dtype: object
# 3469    A Sailboat In The Moonlight
# Name: title, dtype: object
# 3469    Arthur Tracy
# Name: artist.name, dtype: object
# 3490    The Way
# Name: title, dtype: object
# 3490    Saigon Kick
# Name: artist.name, dtype: object
# 3771    I Love You More Than You'll Ever Know (LP Vers...
# Name: title, dtype: object
# 3771    Donny Hathaway
# Name: artist.name, dtype: object
# 3785    Below The Stars
# Name: title, dtype: object
# 3785    The Field Mice
# Name: artist.name, dtype: object
# 4320    Anya
# Name: title, dtype: object
# 4320    Marvin Hamlisch
# Name: artist.name, dtype: object
# 4561    Matilda Mother (Stereo) (2007 Remaster)
# Name: title, dtype: object
# 4561    Pink Floyd
# Name: artist.name, dtype: object
# 5649    Taking Over
# Name: title, dtype: object
# 5649    Big Rich featuring Devo
# Name: artist.name, dtype: object
# 6818    This Is How We Live: Northern Cali
# Name: title, dtype: object
# 6818    Big Rich featuring Devo
# Name: artist.name, dtype: object
# 6872    Getting Old Sucks (Album Version)
# Name: title, dtype: object
# 6872    Bill Engvall
# Name: artist.name, dtype: object
# 7000    Perk trip - sleeping in "tubes
# Name: title, dtype: object
# 7000    Jeanne Robertson
# Name: artist.name, dtype: object
# 7194    Xoanina
# Name: title, dtype: object
# 7194    Susana Seivane
# Name: artist.name, dtype: object
# 7346    Tu Robaste Mi Corazon
# Name: title, dtype: object
# 7346    Selena
# Name: artist.name, dtype: object
# 7387    Flamenco Sketches (Intro)
# Name: title, dtype: object
# 7387    Jason Miles
# Name: artist.name, dtype: object
# 7574    Selling Jolson A Baseball Team
# Name: title, dtype: object
# 7574    Groucho Marx
# Name: artist.name, dtype: object
# 7787    Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo ...
# Name: title, dtype: object
# 7787    Herbert  von Karajan
# Name: artist.name, dtype: object
# 7865    I'm Going Around In Circles
# Name: title, dtype: object
# 7865    Jimmy Witherspoon
# Name: artist.name, dtype: object
# 8156    Standing On The Promises (Palmore) (Beyond The...
# Name: title, dtype: object
# 8156    Daryl Coley
# Name: artist.name, dtype: object
# 8181    Yesterdays
# Name: title, dtype: object
# 8181    Gonzalo Rubalcaba
# Name: artist.name, dtype: object
# 8804    Turn It Around
# Name: title, dtype: object
# 8804    Tony Matterhorn
# Name: artist.name, dtype: object
# 8885    Castle Of My Dreams
# Name: title, dtype: object
# 8885    Tex Williams
# Name: artist.name, dtype: object
# 8982    Nocturne For Piano No. 8 In D Flat Major_ Op. ...
# Name: title, dtype: object
# 8982    David Jalbert
# Name: artist.name, dtype: object
# 9002    Misty
# Name: title, dtype: object
# 9002    King Curtis
# Name: artist.name, dtype: object
# 9009    My Pillow
# Name: title, dtype: object
# 9009    Roger Miller
# Name: artist.name, dtype: object
# 9205    A Distant Voice
# Name: title, dtype: object
# 9205    Sonny Simmons
# Name: artist.name, dtype: object
# 9208    Better Love Next Time Part 2
# Name: title, dtype: object
# 9208    Jimmy Witherspoon
# Name: artist.name, dtype: object
# 9286    Sweet Love
# Name: title, dtype: object
# 9286    Mary Black
# Name: artist.name, dtype: object
# 9401    I'm Kinda Partial To His Puss (from My Square ...
# Name: title, dtype: object
# 9401    Nancy Walker
# Name: artist.name, dtype: object

# %%
dfnew
# Out:
#                  song.id              terms  votes
# 53    SODHOGM12AB018A4FA        horror punk      0
# 1613  SOMBCOW12AAF3B229F            chanson      0
# 1697  SOSNQQX12AF729C44C               rock      0
# 1973  SOPAZAM12A6D4F6F05    religious music      0
# 2025  SOVXPSE12A6D4F87B5                rap      0
# 2536  SOOJHOT12A8C137024  instrumental rock      0
# 2720  SOZXTKD12A8C13FC43          math-core      0
# 2986  SOLTLEZ12AB01886B3              vocal      0
# 3469  SOMTLNK12A58A7A62B         vaudeville      0
# 3490  SOZZFUI12A8C133D6D          hard rock      0
# 3771  SOZNDLW12A6D4FB4C5          jazz funk      0
# 3785  SOQPENF12A8C13D7D8           twee pop      0
# 4320  SOQFLWF12AB017EF20         show tunes      0
# 4561  SOWPTXM12AF729D122           art rock      0
# 5649  SOWTBWY12A582A2823              hyphy      0
# 6818  SOWKBWM12AB01857A4              hyphy      0
# 6872  SOBEMGL12A6D4F9A50             comedy      0
# 7000  SODFJJC12AC468C3F3    stand-up comedy      0
# 7194  SOFZXJY12AC46876EA              gaita      0
# 7346  SOFOHYX12A6D4F814D             tejano      0
# 7387  SODMXRL12A58A7E9C6        jazz fusion      0
# 7574  SOPHMCZ12A81C21C54            doo-wop      0
# 7787  SOJBWKS12A8C135255              opera      0
# 7865  SOADNGK12AB017F955         jazz blues      0
# 8156  SOLKQVW12A6D4F69AB                ccm      0
# 8181  SOAHNZK12A6D4F79A9         latin jazz      0
# 8804  SOBGCFL12AB0185ECE          reggaeton      0
# 8885  SOJDPPG12A8C134780      western swing      0
# 8982  SOYXIYK12A8C138524        los angeles      0
# 9002  SOFWEJY12A8C131DF1  instrumental rock      0
# 9009  SORSEYK12AB01870D6         honky tonk      0
# 9205  SOBLTSM12A6D4F9EEA          free jazz      0
# 9208  SOELNXC12A58A7AFD5         jazz blues      0
# 9286  SOXNVHD12A8C13CD75       country rock      0
# 9401  SOSNWQV12A8C13B736         vaudeville      0

# %%
taglist
# Out:
# ['disco', 'post-disco']
